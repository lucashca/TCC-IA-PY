# %%
from minisom import MiniSom
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img = plt.imread('house.jpeg')

plt.imshow(img)

# %%
pixels = np.reshape(img, (img.shape[0]*img.shape[1], 3))
print(pixels)
# Out:
# [[ 84 118 179]
#  [ 84 118 179]
#  [ 85 119 180]
#  ...
#  [115 130  71]
#  [117 132  73]
#  [114 129  70]]

# %%
som = MiniSom(x= 3, y = 3, input_len = 3, sigma=0.1, learning_rate=0.2)
som.random_weights_init(pixels)
starting_weights = som.get_weights().copy()
som.train_random(pixels, 100)
qnt = som.quantization(pixels)

# %%
clustered = np.zeros(img.shape)
for i, q in enumerate(qnt):
  clustered[np.unravel_index(i, dims=(img.shape[0], img.shape[1]))] = q
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: 'shape' argument should be used instead of 'dims'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(12, 6))
plt.subplot(221)
plt.title('Original')
plt.imshow(img)
plt.subplot(222)
plt.title('Result')
plt.imshow(clustered)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.subplot(223)
plt.title('Initial Colors')
plt.imshow(starting_weights)
plt.subplot(224)
plt.title('Learnt Colors')
plt.imshow(som.get_weights())
# Out:
#   File "<ipython-input-6-7586f02e8b4e>", line 7
#     view raw
#            ^
# SyntaxError: invalid syntax

# %%
plt.tight_layout()
plt.show()

# %%
#
