# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('../datasets/solo.csv')
print(df)
# Out:
#     Nitrogênio Foliar (g/kg)  Fósforo(P) (mg/dm³)  Potássio(K) (cmol c/dm³)  \
# 0                       0.49                 0.29                      0.59
# 1                       0.36                 0.33                      0.69
# 2                       0.59                 0.95                      0.64
# 3                       0.29                 0.37                      0.94
# 4                       0.15                 0.27                      0.38
# 5                       0.29                 0.71                      0.40
# 6                       0.48                 0.56                      0.54
# 7                       0.58                 0.56                      0.92
# 8                       0.17                 0.25                      0.38
# 9                       0.32                 0.02                      0.44
# 10                      0.61                 0.95                      0.03
# ...

# %%
sb.pairplot(df)

# %%
X = np.array(df)
X
# Out:
# array([[0.49, 0.29, 0.59, ..., 0.44, 0.06, 0.7 ],
#        [0.36, 0.33, 0.69, ..., 0.43, 0.11, 0.24],
#        [0.59, 0.95, 0.64, ..., 0.83, 0.87, 0.45],
#        ...,
#        [0.75, 0.36, 0.53, ..., 0.57, 0.27, 0.87],
#        [0.86, 0.01, 0.89, ..., 0.85, 0.12, 0.95],
#        [0.65, 0.04, 0.8 , ..., 0.45, 0.28, 0.02]])

# %% [markdown]
# # K-Means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3,random_state = 0,n_jobs=1,max_iter=5000)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=5000,
#        n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
print(kmeans.labels_)
# Out:
# [2 2 1 0 0 2 0 1 1 1 2 1 0 0 1 1 2 1 1 1 2 1 2 1 2 2 2 1 0 1 2 1 2 1 1 0 1
#  0 2 0 2 0 1 1 2 1 2 2 2 1 1 2 1 1 2 1 1 1 1 1 2 0 2 0 0 0 2 2 2 1 1 0 0 0
#  1 1 2 2 1 0 0 1 1 0 2 1 1 2 1 0 1 2 0 2 2 2 0 1 1 1]

# %% [markdown]
# # Comparando as Classes Criadas

# %%
df['K-classes'] = kmeans.labels_

# %%
df
# Out:
#     Nitrogênio Foliar (g/kg)  Fósforo(P) (mg/dm³)  Potássio(K) (cmol c/dm³)  \
# 0                       0.49                 0.29                      0.59
# 1                       0.36                 0.33                      0.69
# 2                       0.59                 0.95                      0.64
# 3                       0.29                 0.37                      0.94
# 4                       0.15                 0.27                      0.38
# 5                       0.29                 0.71                      0.40
# 6                       0.48                 0.56                      0.54
# 7                       0.58                 0.56                      0.92
# 8                       0.17                 0.25                      0.38
# 9                       0.32                 0.02                      0.44
# 10                      0.61                 0.95                      0.03
# ...

# %%
sb.pairplot(df,hue='K-classes')
